# %% [markdown]
# We will use 360-degree data from the employees of the company to predict the attrition of them. After that we will use classification with deep learning for a better understanding of the data.

# %% [markdown]
# We will use the following data:
#
# - ID: unique employee ID
# - TotalMonthsOfExp: total months of experience
# - TotalOrgsWorked: total organizations worked so far
# - MonthsInOrg: months in current organization
# - LastPayIncrementBand: last pay increment band in a scale of 1 to 5 (1 = highest, 5 = lowest)
# - AverageFeedback: average feedback of the 360-degree feedback survey (1 = highest, 5 = lowest)
# - LastPromotionYears: how many years since the last promotion
# - Attrition: attrition status (1 = yes, 0 = no)

# %% [markdown]
# #### 1. Preprocessing Attrition Data

# %%
# load the dataset and analyze it
import pandas as pd
import numpy as np
import tensorflow as tf

attrition_data = pd.read_csv('./dataset.csv')

print("attrition dataset loaded:")

attrition_data.head()
# Out:
# attrition dataset loaded:
#    EmployeeID  TotalMonthsOfExp  TotalOrgsWorked  MonthsInOrg  \
# 0           1               110                4            9
# 1           2               103                3           51
# 2           3                41                4           16
# 3           4                32                4           17
# 4           5                80                3           16
#
#    LastPayIncrementBand  AverageFeedback  LastPromotionYears  Attrition
# 0                     5                4                   4          1
# 1                     1                4                   2          0
# 2                     5                4                   4          1
# 3                     5                2                   3          0
# 4                     3                4                   2          0

# %%
# correlation analysis of the target attribute
attrition_data.corr()['Attrition']
# Out:
# EmployeeID             -0.036630
# TotalMonthsOfExp        0.019702
# TotalOrgsWorked         0.008706
# MonthsInOrg             0.012605
# LastPayIncrementBand    0.108528
# AverageFeedback        -0.008253
# LastPromotionYears      0.765641
# Attrition               1.000000
# Name: Attrition, dtype: float64

# %%
# convert the DataFrame to a numpy array
converted_attrition_data = attrition_data.to_numpy().astype(float)

# create X_train with the first 7 attributes
X_train = converted_attrition_data[:, 1:7]

# create Y_train with attrition attribute
Y_train = converted_attrition_data[:, 7]

# convert Y_train to one-hot-enconding
Y_train = tf.keras.utils.to_categorical(Y_train, 2)

print("X_train Shape: ", X_train.shape)
print("Y_train Shape: ", Y_train.shape)
# Out:
# X_train Shape:  (1000, 6)
# Y_train Shape:  (1000, 2)

# %% [markdown]
# #### 2. Building The Attrition Model

# %%
from tensorflow import keras

# setup huperparameters for deep learning
EPOCHS = 100
BATCH_SIZE = 100
VERBOSE = 1
NB_CLASSES = 2
N_HIDDEN = 128
VALIDATION_SPLIT = 0.2

# create keras model
model = tf.keras.models.Sequential()

# add first hidden dense layer
model.add(
  keras.layers.Dense(
    N_HIDDEN,
    input_shape=(6,),
    name='Dense-Layer-1',
    activation='relu',
  )
)

# add second hidden dense layer
model.add(
  keras.layers.Dense(
    N_HIDDEN,
    name='Dense-Layer-2',
    activation='relu',
  )
)

# add a final layer with softmax
model.add(
  keras.layers.Dense(
    NB_CLASSES,
    name='Final',
    activation='softmax',
  )
)

# compile the model
model.compile(
  optimizer='adam',
  loss='categorical_crossentropy',
  metrics=['accuracy'],
)

# fit parameters to the model
model.fit(
  X_train,
  Y_train,
  epochs=EPOCHS,
  batch_size=BATCH_SIZE,
  verbose=VERBOSE,
  validation_split=VALIDATION_SPLIT,
)

model.save(filepath='./attrition_model.h5')
# Out:
# Epoch 1/100
# 8/8 [==============================] - 1s 46ms/step - loss: 2.0420 - accuracy: 0.6400 - val_loss: 1.6340 - val_accuracy: 0.7850
# Epoch 2/100
# 8/8 [==============================] - 0s 15ms/step - loss: 1.0223 - accuracy: 0.6288 - val_loss: 0.7948 - val_accuracy: 0.4950
# Epoch 3/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.7210 - accuracy: 0.7362 - val_loss: 0.7178 - val_accuracy: 0.7900
# Epoch 4/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5762 - accuracy: 0.7525 - val_loss: 0.5245 - val_accuracy: 0.7850
# Epoch 5/100
# 8/8 [==============================] - 0s 13ms/step - loss: 0.5297 - accuracy: 0.7862 - val_loss: 0.5093 - val_accuracy: 0.8000
# Epoch 6/100
# 8/8 [==============================] - 0s 13ms/step - loss: 0.4886 - accuracy: 0.7887 - val_loss: 0.4765 - val_accuracy: 0.7950
# Epoch 7/100
# 8/8 [==============================] - 0s 13ms/step - loss: 0.4566 - accuracy: 0.7887 - val_loss: 0.4494 - val_accuracy: 0.8200
# Epoch 8/100
# 8/8 [==============================] - 0s 13ms/step - loss: 0.4413 - accuracy: 0.8138 - val_loss: 0.4435 - val_accuracy: 0.8600
# Epoch 9/100
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4195 - accuracy: 0.8250 - val_loss: 0.4137 - val_accuracy: 0.8300
# Epoch 10/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.3912 - accuracy: 0.8213 - val_loss: 0.3892 - val_accuracy: 0.8350
# Epoch 11/100
# 8/8 [==============================] - 0s 14ms/step - loss: 0.3932 - accuracy: 0.8250 - val_loss: 0.3834 - val_accuracy: 0.8750
# Epoch 12/100
# 8/8 [==============================] - 0s 13ms/step - loss: 0.3656 - accuracy: 0.8400 - val_loss: 0.3533 - val_accuracy: 0.8500
# Epoch 13/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3558 - accuracy: 0.8512 - val_loss: 0.3871 - val_accuracy: 0.8250
# Epoch 14/100
# 8/8 [==============================] - 0s 14ms/step - loss: 0.3514 - accuracy: 0.8325 - val_loss: 0.3405 - val_accuracy: 0.8750
# Epoch 15/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3233 - accuracy: 0.8575 - val_loss: 0.3235 - val_accuracy: 0.8700
# Epoch 16/100
# 8/8 [==============================] - 0s 14ms/step - loss: 0.3103 - accuracy: 0.8637 - val_loss: 0.3199 - val_accuracy: 0.8700
# Epoch 17/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.3012 - accuracy: 0.8737 - val_loss: 0.3011 - val_accuracy: 0.8900
# Epoch 18/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.3023 - accuracy: 0.8700 - val_loss: 0.2967 - val_accuracy: 0.8650
# Epoch 19/100
# 8/8 [==============================] - 0s 14ms/step - loss: 0.2990 - accuracy: 0.8712 - val_loss: 0.2944 - val_accuracy: 0.8700
# Epoch 20/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.3760 - accuracy: 0.8238 - val_loss: 0.2998 - val_accuracy: 0.8800
# Epoch 21/100
# 8/8 [==============================] - 0s 14ms/step - loss: 0.3113 - accuracy: 0.8550 - val_loss: 0.2954 - val_accuracy: 0.8800
# Epoch 22/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.3256 - accuracy: 0.8675 - val_loss: 0.2967 - val_accuracy: 0.9000
# Epoch 23/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.3250 - accuracy: 0.8537 - val_loss: 0.2912 - val_accuracy: 0.8950
# Epoch 24/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.2825 - accuracy: 0.8813 - val_loss: 0.3056 - val_accuracy: 0.9200
# Epoch 25/100
# 8/8 [==============================] - 0s 14ms/step - loss: 0.2845 - accuracy: 0.8850 - val_loss: 0.2783 - val_accuracy: 0.9050
# Epoch 26/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.2606 - accuracy: 0.8938 - val_loss: 0.2754 - val_accuracy: 0.9050
# Epoch 27/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.2522 - accuracy: 0.8938 - val_loss: 0.2889 - val_accuracy: 0.8950
# Epoch 28/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.2590 - accuracy: 0.8963 - val_loss: 0.2970 - val_accuracy: 0.8900
# Epoch 29/100
# 8/8 [==============================] - 0s 12ms/step - loss: 0.2661 - accuracy: 0.8900 - val_loss: 0.2616 - val_accuracy: 0.8750
# Epoch 30/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.2427 - accuracy: 0.8988 - val_loss: 0.2769 - val_accuracy: 0.9050
# Epoch 31/100
# 8/8 [==============================] - 0s 13ms/step - loss: 0.2418 - accuracy: 0.9000 - val_loss: 0.2945 - val_accuracy: 0.8800
# Epoch 32/100
# 8/8 [==============================] - 0s 14ms/step - loss: 0.2492 - accuracy: 0.9000 - val_loss: 0.2506 - val_accuracy: 0.9250
# Epoch 33/100
# 8/8 [==============================] - 0s 14ms/step - loss: 0.2342 - accuracy: 0.9125 - val_loss: 0.2407 - val_accuracy: 0.9000
# Epoch 34/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.2142 - accuracy: 0.9250 - val_loss: 0.2272 - val_accuracy: 0.9000
# Epoch 35/100
# 8/8 [==============================] - 0s 12ms/step - loss: 0.2131 - accuracy: 0.9200 - val_loss: 0.2224 - val_accuracy: 0.9100
# Epoch 36/100
# 8/8 [==============================] - 0s 13ms/step - loss: 0.2406 - accuracy: 0.8900 - val_loss: 0.2232 - val_accuracy: 0.9200
# Epoch 37/100
# 8/8 [==============================] - 0s 14ms/step - loss: 0.2052 - accuracy: 0.9237 - val_loss: 0.2338 - val_accuracy: 0.9300
# Epoch 38/100
# 8/8 [==============================] - 0s 13ms/step - loss: 0.2063 - accuracy: 0.9150 - val_loss: 0.2206 - val_accuracy: 0.9250
# Epoch 39/100
# 8/8 [==============================] - 0s 14ms/step - loss: 0.2338 - accuracy: 0.9038 - val_loss: 0.3077 - val_accuracy: 0.8700
# Epoch 40/100
# 8/8 [==============================] - 0s 13ms/step - loss: 0.2568 - accuracy: 0.8975 - val_loss: 0.3255 - val_accuracy: 0.8450
# Epoch 41/100
# 8/8 [==============================] - 0s 14ms/step - loss: 0.2181 - accuracy: 0.9212 - val_loss: 0.2185 - val_accuracy: 0.9050
# Epoch 42/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.2029 - accuracy: 0.9225 - val_loss: 0.2176 - val_accuracy: 0.9250
# Epoch 43/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.2054 - accuracy: 0.9187 - val_loss: 0.2343 - val_accuracy: 0.9150
# Epoch 44/100
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1961 - accuracy: 0.9237 - val_loss: 0.2028 - val_accuracy: 0.9200
# Epoch 45/100
# 8/8 [==============================] - 0s 13ms/step - loss: 0.1954 - accuracy: 0.9275 - val_loss: 0.2152 - val_accuracy: 0.9050
# Epoch 46/100
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1876 - accuracy: 0.9312 - val_loss: 0.2332 - val_accuracy: 0.8750
# Epoch 47/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.2022 - accuracy: 0.9325 - val_loss: 0.2024 - val_accuracy: 0.9300
# Epoch 48/100
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1870 - accuracy: 0.9312 - val_loss: 0.1933 - val_accuracy: 0.9350
# Epoch 49/100
# 8/8 [==============================] - 0s 13ms/step - loss: 0.1679 - accuracy: 0.9400 - val_loss: 0.1843 - val_accuracy: 0.9400
# Epoch 50/100
# 8/8 [==============================] - 0s 13ms/step - loss: 0.1812 - accuracy: 0.9337 - val_loss: 0.1965 - val_accuracy: 0.9400
# Epoch 51/100
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1910 - accuracy: 0.9275 - val_loss: 0.2038 - val_accuracy: 0.9050
# Epoch 52/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1908 - accuracy: 0.9200 - val_loss: 0.1980 - val_accuracy: 0.9150
# Epoch 53/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1644 - accuracy: 0.9362 - val_loss: 0.2052 - val_accuracy: 0.9000
# Epoch 54/100
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1603 - accuracy: 0.9525 - val_loss: 0.1876 - val_accuracy: 0.9200
# Epoch 55/100
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1668 - accuracy: 0.9438 - val_loss: 0.2544 - val_accuracy: 0.8650
# Epoch 56/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.1884 - accuracy: 0.9162 - val_loss: 0.1924 - val_accuracy: 0.9150
# Epoch 57/100
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1651 - accuracy: 0.9463 - val_loss: 0.1702 - val_accuracy: 0.9400
# Epoch 58/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.1611 - accuracy: 0.9463 - val_loss: 0.1887 - val_accuracy: 0.9050
# Epoch 59/100
# 8/8 [==============================] - 0s 13ms/step - loss: 0.1671 - accuracy: 0.9300 - val_loss: 0.2448 - val_accuracy: 0.8750
# Epoch 60/100
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1833 - accuracy: 0.9212 - val_loss: 0.2268 - val_accuracy: 0.8800
# Epoch 61/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.1571 - accuracy: 0.9362 - val_loss: 0.1757 - val_accuracy: 0.9150
# Epoch 62/100
# 8/8 [==============================] - 0s 13ms/step - loss: 0.1585 - accuracy: 0.9325 - val_loss: 0.1771 - val_accuracy: 0.9300
# Epoch 63/100
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1560 - accuracy: 0.9388 - val_loss: 0.1565 - val_accuracy: 0.9550
# Epoch 64/100
# 8/8 [==============================] - 0s 13ms/step - loss: 0.1528 - accuracy: 0.9463 - val_loss: 0.2859 - val_accuracy: 0.8500
# Epoch 65/100
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1910 - accuracy: 0.9212 - val_loss: 0.1690 - val_accuracy: 0.9200
# Epoch 66/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.1689 - accuracy: 0.9275 - val_loss: 0.1828 - val_accuracy: 0.9250
# Epoch 67/100
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1967 - accuracy: 0.9137 - val_loss: 0.1810 - val_accuracy: 0.9150
# Epoch 68/100
# 8/8 [==============================] - 0s 13ms/step - loss: 0.1550 - accuracy: 0.9463 - val_loss: 0.1479 - val_accuracy: 0.9550
# Epoch 69/100
# 8/8 [==============================] - 0s 13ms/step - loss: 0.1294 - accuracy: 0.9625 - val_loss: 0.1401 - val_accuracy: 0.9550
# Epoch 70/100
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1321 - accuracy: 0.9613 - val_loss: 0.1526 - val_accuracy: 0.9300
# Epoch 71/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.1292 - accuracy: 0.9613 - val_loss: 0.1387 - val_accuracy: 0.9600
# Epoch 72/100
# 8/8 [==============================] - 0s 13ms/step - loss: 0.1244 - accuracy: 0.9613 - val_loss: 0.1374 - val_accuracy: 0.9550
# Epoch 73/100
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1147 - accuracy: 0.9688 - val_loss: 0.1360 - val_accuracy: 0.9550
# Epoch 74/100
# 8/8 [==============================] - 0s 13ms/step - loss: 0.1618 - accuracy: 0.9350 - val_loss: 0.3065 - val_accuracy: 0.8700
# Epoch 75/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.2000 - accuracy: 0.9175 - val_loss: 0.3270 - val_accuracy: 0.8550
# Epoch 76/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.1774 - accuracy: 0.9187 - val_loss: 0.1647 - val_accuracy: 0.9300
# Epoch 77/100
# 8/8 [==============================] - 0s 13ms/step - loss: 0.1273 - accuracy: 0.9563 - val_loss: 0.1363 - val_accuracy: 0.9500
# Epoch 78/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1140 - accuracy: 0.9712 - val_loss: 0.1301 - val_accuracy: 0.9550
# Epoch 79/100
# 8/8 [==============================] - 0s 12ms/step - loss: 0.1055 - accuracy: 0.9775 - val_loss: 0.1217 - val_accuracy: 0.9600
# Epoch 80/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.1029 - accuracy: 0.9762 - val_loss: 0.1690 - val_accuracy: 0.9100
# Epoch 81/100
# 8/8 [==============================] - 0s 13ms/step - loss: 0.1367 - accuracy: 0.9450 - val_loss: 0.1636 - val_accuracy: 0.9100
# Epoch 82/100
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1488 - accuracy: 0.9388 - val_loss: 0.1385 - val_accuracy: 0.9500
# Epoch 83/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1229 - accuracy: 0.9613 - val_loss: 0.1395 - val_accuracy: 0.9500
# Epoch 84/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1004 - accuracy: 0.9737 - val_loss: 0.1177 - val_accuracy: 0.9550
# Epoch 85/100
# 8/8 [==============================] - 0s 13ms/step - loss: 0.0959 - accuracy: 0.9800 - val_loss: 0.1204 - val_accuracy: 0.9550
# Epoch 86/100
# 8/8 [==============================] - 0s 13ms/step - loss: 0.0981 - accuracy: 0.9787 - val_loss: 0.1167 - val_accuracy: 0.9600
# Epoch 87/100
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0904 - accuracy: 0.9887 - val_loss: 0.1165 - val_accuracy: 0.9600
# Epoch 88/100
# 8/8 [==============================] - 0s 13ms/step - loss: 0.0898 - accuracy: 0.9875 - val_loss: 0.1298 - val_accuracy: 0.9450
# Epoch 89/100
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0870 - accuracy: 0.9825 - val_loss: 0.1087 - val_accuracy: 0.9650
# Epoch 90/100
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0872 - accuracy: 0.9812 - val_loss: 0.1243 - val_accuracy: 0.9500
# Epoch 91/100
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1009 - accuracy: 0.9762 - val_loss: 0.1052 - val_accuracy: 0.9650
# Epoch 92/100
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0891 - accuracy: 0.9787 - val_loss: 0.1324 - val_accuracy: 0.9400
# Epoch 93/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.1014 - accuracy: 0.9663 - val_loss: 0.1756 - val_accuracy: 0.8950
# Epoch 94/100
# 8/8 [==============================] - 0s 13ms/step - loss: 0.1885 - accuracy: 0.9262 - val_loss: 0.1394 - val_accuracy: 0.9300
# Epoch 95/100
# 8/8 [==============================] - 0s 13ms/step - loss: 0.1558 - accuracy: 0.9300 - val_loss: 0.1832 - val_accuracy: 0.9100
# Epoch 96/100
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1130 - accuracy: 0.9525 - val_loss: 0.1360 - val_accuracy: 0.9550
# Epoch 97/100
# 8/8 [==============================] - 0s 23ms/step - loss: 0.0984 - accuracy: 0.9737 - val_loss: 0.1167 - val_accuracy: 0.9700
# Epoch 98/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0832 - accuracy: 0.9812 - val_loss: 0.0993 - val_accuracy: 0.9600
# Epoch 99/100
# 8/8 [==============================] - 0s 13ms/step - loss: 0.0951 - accuracy: 0.9688 - val_loss: 0.1013 - val_accuracy: 0.9600
# Epoch 100/100
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0770 - accuracy: 0.9812 - val_loss: 0.1000 - val_accuracy: 0.9650

# %% [markdown]
# #### 3. Predicting Attrition

# %%
def get_prediction_result(results: list):
  new_list = []

  for result in results:
    if result == 0:
      new_list.append('No')
    else:
      new_list.append('Yes')

  return new_list

# %%
# defining a test data to predict a single employee attrition
TOTAL_MONTHS_OF_EXP = 40
TOTAL_ORGS_WORKED = 4
MONTHS_IN_ORG = 20
LAST_PAY_INCREMENT_BAND = 5
AVERAGE_FEEDBACK_BAND = 4
LAST_PROMOTION_YEARS = 4

TEST_DATA = [
  [
    TOTAL_MONTHS_OF_EXP, 
    TOTAL_ORGS_WORKED, 
    MONTHS_IN_ORG, 
    LAST_PAY_INCREMENT_BAND, 
    AVERAGE_FEEDBACK_BAND, 
    LAST_PROMOTION_YEARS
  ]
]

single_employee_prediction = model.predict(TEST_DATA)
single_employee_prediction_result = np.argmax(single_employee_prediction, axis = 1)

print('Will the employee leave the company?', get_prediction_result(single_employee_prediction_result)[0])
# Out:
# 1/1 [==============================] - 0s 212ms/step
# Will the employee leave the company? Yes

# %%
# defining a test data to predict multiple employees attrition
TEST_DATA = [
  [111, 5, 85, 3, 2, 2],
  [31, 2, 15, 4, 1, 4],
  [61, 4, 24, 1, 4, 3],
  [77, 4, 35, 3, 1, 1],
  [81, 5, 7, 1, 2, 3],
  [113, 4, 112, 5, 4, 1],
  [101, 2, 48, 5, 1, 4],
  [45, 4, 22, 5, 3, 1],
  [25, 2, 2, 2, 3, 2],
  [97, 3, 15, 3, 2, 4]
]

multiple_employees_prediction = model.predict(TEST_DATA)
multiple_employees_prediction_result = np.argmax(multiple_employees_prediction, axis = 1)

print('Will the employees leave the company?', get_prediction_result(multiple_employees_prediction_result))
# Out:
# 1/1 [==============================] - 0s 56ms/step
# Will the employees leave the company? ['No', 'Yes', 'No', 'No', 'No', 'No', 'Yes', 'No', 'No', 'Yes']
